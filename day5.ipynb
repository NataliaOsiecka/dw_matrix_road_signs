# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaOsiecka/dw_matrix_road_signs/blob/master/day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.38.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
import datetime
import pandas as pd
import numpy as np
import os

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical

# %load_ext tensorboard

import matplotlib.pyplot as plt
from skimage import color, exposure
from sklearn.metrics import accuracy_score

from hyperopt import hp, STATUS_OK, tpe, Trials, fmin

# %%
cd '/content/drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_signs'
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_signs

# %%
train = pd.read_pickle('data/train.p')
test = pd.read_pickle('data/test.p')

X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

# %%
if y_train.ndim == 1: y_train = to_categorical(y_train)
if y_test.ndim == 1: y_test = to_categorical(y_test)

input_shape = X_train.shape[1:]
num_classes = y_train.shape[1]

# %%
def train_model(model, X_train, y_train, params_fit={}):
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
  logdir = os.path.join('logs', datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

  model.fit(
      X_train, 
      y_train,
      batch_size=params_fit.get('batch_size', 128),
      epochs=params_fit.get('epochs', 5),
      verbose=params_fit.get('verbose', 1),
      validation_data=params_fit.get('validation_data', (X_train, y_train)),
      callbacks=[tensorboard_callback]
      )
  return model

# %%
def predict(model_trained, X_test, y_test, scoring=accuracy_score):

  y_test_norm = np.argmax(y_test, axis=1)

  y_pred_prob = model_trained.predict(X_test)
  y_pred = np.argmax(y_pred_prob, axis=1)

  return scoring(y_test_norm, y_pred)

# %%
def get_cnn_v5(input_shape, num_classes):
  return Sequential([
  Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=input_shape),
  Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same'),
  MaxPool2D(),
  Dropout(0.3),

  Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
  Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
  MaxPool2D(),
  Dropout(0.3),

  Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
  Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
  MaxPool2D(),
  Dropout(0.3),

  Flatten(),

  Dense(1024, activation='relu'),
  Dropout(0.3),

  Dense(1024, activation='relu'),
  Dropout(0.3),

  Dense(num_classes, activation='softmax'),
  ])

#train_and_predict(get_cnn_v5(input_shape, num_classes))

# %%
model = get_cnn_v5(input_shape, num_classes)
model_trained = train_model(model, X_train, y_train)

predict(model_trained, X_test, y_test)
# Out:
# Epoch 1/5
# 272/272 [==============================] - 5s 19ms/step - loss: 2.7468 - accuracy: 0.2664 - val_loss: 1.0643 - val_accuracy: 0.6428
# Epoch 2/5
# 272/272 [==============================] - 5s 17ms/step - loss: 0.9620 - accuracy: 0.6931 - val_loss: 0.3628 - val_accuracy: 0.9024
# Epoch 3/5
# 272/272 [==============================] - 5s 17ms/step - loss: 0.5402 - accuracy: 0.8300 - val_loss: 0.1454 - val_accuracy: 0.9541
# Epoch 4/5
# 272/272 [==============================] - 5s 18ms/step - loss: 0.3683 - accuracy: 0.8853 - val_loss: 0.0833 - val_accuracy: 0.9759
# Epoch 5/5
# 272/272 [==============================] - 5s 18ms/step - loss: 0.2708 - accuracy: 0.9161 - val_loss: 0.0694 - val_accuracy: 0.9784
# 0.9571428571428572

# %%
def func_obj(params):
  model = get_model(params)
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
  
  model.fit(
      X_train, 
      y_train,
      batch_size=int(params.get('batch_size', 128)),
      epochs=5,
      verbose=0,
      )
  
  accuracy = model.evaluate(X_test, y_test)[0]
  print(params, 'accuracy={}'.format(accuracy))
  return {'loss': -accuracy, 'status': STATUS_OK, 'model': model}

# %%
space = {
    'batch_size':hp.quniform('batch_size', 50, 200, 20)
}

best = fmin(
    func_obj, 
    space,
    tpe.suggest,
    1,
    Trials()
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s, best loss: ?]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-de128b3863d0> in <module>()
#       8     tpe.suggest,
#       9     1,
# ---> 10     Trials()
#      11 )
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     386             catch_eval_exceptions=catch_eval_exceptions,
#     387             return_argmin=return_argmin,
# --> 388             show_progressbar=show_progressbar,
#     389         )
#     390
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar)
#     637             catch_eval_exceptions=catch_eval_exceptions,
#     638             return_argmin=return_argmin,
# --> 639             show_progressbar=show_progressbar)
#     640
#     641
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     405                     show_progressbar=show_progressbar)
#     406     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 407     rval.exhaust()
#     408     if return_argmin:
#     409         return trials.argmin
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in exhaust(self)
#     260     def exhaust(self):
#     261         n_done = len(self.trials)
# --> 262         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     263         self.trials.refresh()
#     264         return self
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     225                     else:
#     226                         # -- loop over trials and do the jobs directly
# --> 227                         self.serial_evaluate()
#     228
#     229                     try:
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#     139                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     140                 try:
# --> 141                     result = self.domain.evaluate(spec, ctrl)
#     142                 except Exception as e:
#     143                     logger.info('job exception: %s' % str(e))
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/base.py in evaluate(self, config, ctrl, attach_attachments)
#     842                 memo=memo,
#     843                 print_node_on_error=self.rec_eval_print_node_on_error)
# --> 844             rval = self.fn(pyll_rval)
#     845
#     846         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-11-48074f6fe9eb> in func_obj(params)
#       1 def func_obj(params):
# ----> 2   model = get_model(params)
#       3   model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
#       4
#       5   model.fit(
#
# NameError: name 'get_model' is not defined
#
# ---------------------------------------------------------------------------
# NOTE: Current TensorFlow version is 2.2.0-rc2. To use TF 1.x instead,
# restart your runtime (Ctrl+M .) and run "%tensorflow_version 1.x" before
# you run "import tensorflow".
# ---------------------------------------------------------------------------

# %%
def get_model(params):
  return Sequential([
  Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=input_shape),
  Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same'),
  MaxPool2D(),
  Dropout(params['dropout_cnn_block_one']),

  Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
  Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
  MaxPool2D(),
  Dropout(params['dropout_cnn_block_two']),

  Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'),
  Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
  MaxPool2D(),
  Dropout(params['dropout_cnn_block_three']),

  Flatten(),

  Dense(1024, activation='relu'),
  Dropout(params['dropout_dense_block_one']),

  Dense(1024, activation='relu'),
  Dropout(params['dropout_dense_block_two']),

  Dense(num_classes, activation='softmax'),
  ])

#train_and_predict(get_cnn_v5(input_shape, num_classes))

# %%
space = {
    'batch_size':hp.quniform('batch_size', 100, 200, 10),
    'dropout_cnn_block_one': hp.uniform('dropout_cnn_block_one', 0.3, 0.5),
    'dropout_cnn_block_two': hp.uniform('dropout_cnn_block_two', 0.3, 0.5),
    'dropout_cnn_block_three': hp.uniform('dropout_cnn_block_three', 0.3, 0.5),

    'dropout_dense_block_one': hp.uniform('dropout_dense_block_one', 0.3, 0.7),
    'dropout_dense_block_two': hp.uniform('dropout_dense_block_two', 0.3, 0.7),
}

best = fmin(
    func_obj, 
    space,
    tpe.suggest,
    30,
    Trials()
)
# Out:
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.1675 - accuracy: 0.6875
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 0.2452 - accuracy: 0.9333
#
#  27/138 [====>.........................]
#  - ETA: 0s - loss: 0.2587 - accuracy: 0.9225
#
#  41/138 [=======>......................]
#  - ETA: 0s - loss: 0.1884 - accuracy: 0.9451
#
#  54/138 [==========>...................]
#  - ETA: 0s - loss: 0.2594 - accuracy: 0.9265
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 0.2381 - accuracy: 0.9318
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 0.2034 - accuracy: 0.9419
#
#  89/138 [==================>...........]
#  - ETA: 0s - loss: 0.1848 - accuracy: 0.9470
#
# 102/138 [=====================>........]
#  - ETA: 0s - loss: 0.2140 - accuracy: 0.9396
#
# 112/138 [=======================>......]
#  - ETA: 0s - loss: 0.2141 - accuracy: 0.9406
#
# 122/138 [=========================>....]
#  - ETA: 0s - loss: 0.2013 - accuracy: 0.9439
#
# 134/138 [============================>.]
#  - ETA: 0s - loss: 0.2046 - accuracy: 0.9368
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.2033 - accuracy: 0.9374
#
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.4505153713787763, 'dropout_cnn_block_three': 0.43622741752355965, 'dropout_cnn_block_two': 0.4756971598735117, 'dropout_dense_block_one': 0.38264423330831426, 'dropout_dense_block_two': 0.5470855489717245}
# accuracy=0.20333021879196167
#   1/138 [..............................]
#  - ETA: 0s - loss: 3.1200 - accuracy: 0.0625
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 0.6270 - accuracy: 0.8438
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 0.9607 - accuracy: 0.8193
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 0.7450 - accuracy: 0.8333
#
#  49/138 [=========>....................]
#  - ETA: 0s - loss: 0.8157 - accuracy: 0.7704
#
#  61/138 [============>.................]
#  - ETA: 0s - loss: 0.7832 - accuracy: 0.7797
#
#  70/138 [==============>...............]
#  - ETA: 0s - loss: 0.7224 - accuracy: 0.8013
#
#  83/138 [=================>............]
#  - ETA: 0s - loss: 0.6186 - accuracy: 0.8313
#
#  96/138 [===================>..........]
#  - ETA: 0s - loss: 0.5471 - accuracy: 0.8529
#
# 108/138 [======================>.......]
#  - ETA: 0s - loss: 0.5632 - accuracy: 0.8380
#
# 121/138 [=========================>....]
#  - ETA: 0s - loss: 0.5272 - accuracy: 0.8414
#
# 133/138 [===========================>..]
#  - ETA: 0s - loss: 0.4839 - accuracy: 0.8548
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.4802 - accuracy: 0.8576
#
# {'batch_size': 170.0, 'dropout_cnn_block_one': 0.31065468492702714, 'dropout_cnn_block_three': 0.4131102803115811, 'dropout_cnn_block_two': 0.38583413247263354, 'dropout_dense_block_one': 0.6642213203659846, 'dropout_dense_block_two': 0.6371567076794744}
# accuracy=0.48024699091911316
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.3024 - accuracy: 0.8750
#
#  16/138 [==>...........................]
#  - ETA: 0s - loss: 0.1672 - accuracy: 0.9551
#
#  29/138 [=====>........................]
#  - ETA: 0s - loss: 0.2055 - accuracy: 0.9364
#
#  43/138 [========>.....................]
#  - ETA: 0s - loss: 0.1647 - accuracy: 0.9455
#
#  56/138 [===========>..................]
#  - ETA: 0s - loss: 0.1629 - accuracy: 0.9503
#
#  69/138 [==============>...............]
#  - ETA: 0s - loss: 0.1748 - accuracy: 0.9457
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.1496 - accuracy: 0.9537
#
#  94/138 [===================>..........]
#  - ETA: 0s - loss: 0.1336 - accuracy: 0.9591
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.1469 - accuracy: 0.9584
#
# 114/138 [=======================>......]
#  - ETA: 0s - loss: 0.1367 - accuracy: 0.9613
#
# 127/138 [==========================>...]
#  - ETA: 0s - loss: 0.1314 - accuracy: 0.9616
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.1298 - accuracy: 0.9626
#
# {'batch_size': 170.0, 'dropout_cnn_block_one': 0.42075601360903525, 'dropout_cnn_block_three': 0.31473410521623607, 'dropout_cnn_block_two': 0.3146737749394094, 'dropout_dense_block_one': 0.4172585683609719, 'dropout_dense_block_two': 0.6149118190002199}
# accuracy=0.12984105944633484
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.4408 - accuracy: 0.8750
#
#  16/138 [==>...........................]
#  - ETA: 0s - loss: 0.1775 - accuracy: 0.9453
#
#  28/138 [=====>........................]
#  - ETA: 0s - loss: 0.2755 - accuracy: 0.9096
#
#  41/138 [=======>......................]
#  - ETA: 0s - loss: 0.2214 - accuracy: 0.9245
#
#  54/138 [==========>...................]
#  - ETA: 0s - loss: 0.2157 - accuracy: 0.9300
#
#  67/138 [=============>................]
#  - ETA: 0s - loss: 0.2190 - accuracy: 0.9296
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 0.1948 - accuracy: 0.9367
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.1990 - accuracy: 0.9355
#
# 105/138 [=====================>........]
#  - ETA: 0s - loss: 0.2213 - accuracy: 0.9307
#
# 117/138 [========================>.....]
#  - ETA: 0s - loss: 0.2008 - accuracy: 0.9370
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.1867 - accuracy: 0.9418
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.1790 - accuracy: 0.9447
#
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.4359457396209342, 'dropout_cnn_block_three': 0.4226593782292524, 'dropout_cnn_block_two': 0.36456938978872694, 'dropout_dense_block_one': 0.5440871273383941, 'dropout_dense_block_two': 0.3593525865701306}
# accuracy=0.17899949848651886
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.1312 - accuracy: 0.4375
#
#  16/138 [==>...........................]
#  - ETA: 0s - loss: 0.2283 - accuracy: 0.9219
#
#  29/138 [=====>........................]
#  - ETA: 0s - loss: 0.5139 - accuracy: 0.9030
#
#  42/138 [========>.....................]
#  - ETA: 0s - loss: 0.3650 - accuracy: 0.9308
#
#  56/138 [===========>..................]
#  - ETA: 0s - loss: 0.3549 - accuracy: 0.9241
#
#  69/138 [==============>...............]
#  - ETA: 0s - loss: 0.3263 - accuracy: 0.9248
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.2819 - accuracy: 0.9344
#
#  93/138 [===================>..........]
#  - ETA: 0s - loss: 0.2515 - accuracy: 0.9415
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.2440 - accuracy: 0.9431
#
# 116/138 [========================>.....]
#  - ETA: 0s - loss: 0.2235 - accuracy: 0.9477
#
# 127/138 [==========================>...]
#  - ETA: 0s - loss: 0.2146 - accuracy: 0.9481
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.2069 - accuracy: 0.9490
#
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.45098851913435006, 'dropout_cnn_block_three': 0.3364142942137333, 'dropout_cnn_block_two': 0.3016693273336995, 'dropout_dense_block_one': 0.4178446633848337, 'dropout_dense_block_two': 0.5686387487326572}
# accuracy=0.20687802135944366
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.3298 - accuracy: 0.4375
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 0.2319 - accuracy: 0.9167
#
#  29/138 [=====>........................]
#  - ETA: 0s - loss: 0.3440 - accuracy: 0.9095
#
#  42/138 [========>.....................]
#  - ETA: 0s - loss: 0.2807 - accuracy: 0.9196
#
#  53/138 [==========>...................]
#  - ETA: 0s - loss: 0.2925 - accuracy: 0.9098
#
#  64/138 [============>.................]
#  - ETA: 0s - loss: 0.2590 - accuracy: 0.9189
#
#  76/138 [===============>..............]
#  - ETA: 0s - loss: 0.2361 - accuracy: 0.9260
#
#  90/138 [==================>...........]
#  - ETA: 0s - loss: 0.2039 - accuracy: 0.9358
#
# 104/138 [=====================>........]
#  - ETA: 0s - loss: 0.2163 - accuracy: 0.9303
#
# 115/138 [========================>.....]
#  - ETA: 0s - loss: 0.2043 - accuracy: 0.9348
#
# 125/138 [==========================>...]
#  - ETA: 0s - loss: 0.1883 - accuracy: 0.9398
#
# 138/138 [==============================]
#  - ETA: 0s - loss: 0.1852 - accuracy: 0.9408
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.1852 - accuracy: 0.9408
#
# {'batch_size': 180.0, 'dropout_cnn_block_one': 0.3706237674700137, 'dropout_cnn_block_three': 0.4055338399384828, 'dropout_cnn_block_two': 0.32735967055477777, 'dropout_dense_block_one': 0.3664878110204816, 'dropout_dense_block_two': 0.5402377278933501}
# accuracy=0.18516948819160461
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.9371 - accuracy: 0.0625
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 0.6821 - accuracy: 0.7646
#
#  29/138 [=====>........................]
#  - ETA: 0s - loss: 0.8932 - accuracy: 0.7705
#
#  41/138 [=======>......................]
#  - ETA: 0s - loss: 0.7116 - accuracy: 0.8178
#
#  54/138 [==========>...................]
#  - ETA: 0s - loss: 0.7969 - accuracy: 0.7668
#
#  67/138 [=============>................]
#  - ETA: 0s - loss: 0.7323 - accuracy: 0.7901
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.6322 - accuracy: 0.8167
#
#  90/138 [==================>...........]
#  - ETA: 0s - loss: 0.5839 - accuracy: 0.8319
#
# 102/138 [=====================>........]
#  - ETA: 0s - loss: 0.6105 - accuracy: 0.8061
#
# 114/138 [=======================>......]
#  - ETA: 0s - loss: 0.6082 - accuracy: 0.8010
#
# 125/138 [==========================>...]
#  - ETA: 0s - loss: 0.5640 - accuracy: 0.8163
#
# 136/138 [============================>.]
#  - ETA: 0s - loss: 0.5574 - accuracy: 0.8185
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.5555 - accuracy: 0.8195
#
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.4911331041858256, 'dropout_cnn_block_three': 0.3868174085630386, 'dropout_cnn_block_two': 0.3904688770531141, 'dropout_dense_block_one': 0.4347257961331768, 'dropout_dense_block_two': 0.6077238056731883}
# accuracy=0.55552738904953
#   1/138 [..............................]
#  - ETA: 0s - loss: 3.2863 - accuracy: 0.0625
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.3669 - accuracy: 0.9107
#
#  26/138 [====>.........................]
#  - ETA: 0s - loss: 0.5376 - accuracy: 0.8822
#
#  39/138 [=======>......................]
#  - ETA: 0s - loss: 0.3912 - accuracy: 0.9038
#
#  51/138 [==========>...................]
#  - ETA: 0s - loss: 0.4136 - accuracy: 0.8873
#
#  63/138 [============>.................]
#  - ETA: 0s - loss: 0.3626 - accuracy: 0.9023
#
#  75/138 [===============>..............]
#  - ETA: 0s - loss: 0.3904 - accuracy: 0.8804
#
#  87/138 [=================>............]
#  - ETA: 0s - loss: 0.3480 - accuracy: 0.8958
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.3118 - accuracy: 0.9075
#
# 108/138 [======================>.......]
#  - ETA: 0s - loss: 0.3705 - accuracy: 0.8889
#
# 117/138 [========================>.....]
#  - ETA: 0s - loss: 0.3456 - accuracy: 0.8961
#
# 127/138 [==========================>...]
#  - ETA: 0s - loss: 0.3255 - accuracy: 0.9011
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.3188 - accuracy: 0.9016
#
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.40956276076569786, 'dropout_cnn_block_three': 0.4037394311131262, 'dropout_cnn_block_two': 0.4837807669001948, 'dropout_dense_block_one': 0.3285909664695497, 'dropout_dense_block_two': 0.5826794108545506}
# accuracy=0.31880220770835876
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.2892 - accuracy: 0.2812
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 0.2943 - accuracy: 0.8958
#
#  27/138 [====>.........................]
#  - ETA: 0s - loss: 0.3764 - accuracy: 0.8819
#
#  39/138 [=======>......................]
#  - ETA: 0s - loss: 0.2969 - accuracy: 0.8990
#
#  53/138 [==========>...................]
#  - ETA: 0s - loss: 0.3415 - accuracy: 0.8791
#
#  67/138 [=============>................]
#  - ETA: 0s - loss: 0.2947 - accuracy: 0.8974
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.2459 - accuracy: 0.9147
#
#  93/138 [===================>..........]
#  - ETA: 0s - loss: 0.2218 - accuracy: 0.9244
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.2639 - accuracy: 0.9151
#
# 120/138 [=========================>....]
#  - ETA: 0s - loss: 0.2403 - accuracy: 0.9240
#
# 131/138 [===========================>..]
#  - ETA: 0s - loss: 0.2302 - accuracy: 0.9258
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.2270 - accuracy: 0.9274
#
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.33731464085518303, 'dropout_cnn_block_three': 0.3434392039739234, 'dropout_cnn_block_two': 0.4858869144703802, 'dropout_dense_block_one': 0.562092637666229, 'dropout_dense_block_two': 0.5085265761362269}
# accuracy=0.22700399160385132
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.4927 - accuracy: 0.0625
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.5667 - accuracy: 0.8415
#
#  27/138 [====>.........................]
#  - ETA: 0s - loss: 0.6700 - accuracy: 0.8322
#
#  37/138 [=======>......................]
#  - ETA: 0s - loss: 0.6283 - accuracy: 0.8345
#
#  49/138 [=========>....................]
#  - ETA: 0s - loss: 0.7869 - accuracy: 0.7781
#
#  64/138 [============>.................]
#  - ETA: 0s - loss: 0.6731 - accuracy: 0.8066
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 0.6207 - accuracy: 0.8226
#
#  91/138 [==================>...........]
#  - ETA: 0s - loss: 0.5672 - accuracy: 0.8403
#
# 102/138 [=====================>........]
#  - ETA: 0s - loss: 0.6100 - accuracy: 0.8177
#
# 114/138 [=======================>......]
#  - ETA: 0s - loss: 0.6226 - accuracy: 0.7977
#
# 128/138 [==========================>...]
#  - ETA: 0s - loss: 0.5855 - accuracy: 0.8066
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.5735 - accuracy: 0.8138
#
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.3174654631863406, 'dropout_cnn_block_three': 0.4958975533104408, 'dropout_cnn_block_two': 0.4605987026546887, 'dropout_dense_block_one': 0.699171438639573, 'dropout_dense_block_two': 0.489451667923134}
# accuracy=0.5734657049179077
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.1481 - accuracy: 0.9062
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 0.0801 - accuracy: 0.9667
#
#  28/138 [=====>........................]
#  - ETA: 0s - loss: 0.2748 - accuracy: 0.9408
#
#  42/138 [========>.....................]
#  - ETA: 0s - loss: 0.2051 - accuracy: 0.9524
#
#  55/138 [==========>...................]
#  - ETA: 0s - loss: 0.1780 - accuracy: 0.9602
#
#  65/138 [=============>................]
#  - ETA: 0s - loss: 0.1577 - accuracy: 0.9654
#
#  80/138 [================>.............]
#  - ETA: 0s - loss: 0.1340 - accuracy: 0.9707
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.1390 - accuracy: 0.9654
#
# 105/138 [=====================>........]
#  - ETA: 0s - loss: 0.1501 - accuracy: 0.9631
#
# 117/138 [========================>.....]
#  - ETA: 0s - loss: 0.1347 - accuracy: 0.9669
#
# 128/138 [==========================>...]
#  - ETA: 0s - loss: 0.1269 - accuracy: 0.9692
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.1279 - accuracy: 0.9683
#
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.45446419096590673, 'dropout_cnn_block_three': 0.32317895253583634, 'dropout_cnn_block_two': 0.35845747257079563, 'dropout_dense_block_one': 0.49123164960624616, 'dropout_dense_block_two': 0.3054173081259967}
# accuracy=0.12792786955833435
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.7954 - accuracy: 0.7188
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 0.2917 - accuracy: 0.9167
#
#  28/138 [=====>........................]
#  - ETA: 0s - loss: 0.4360 - accuracy: 0.8996
#
#  40/138 [=======>......................]
#  - ETA: 0s - loss: 0.3231 - accuracy: 0.9273
#
#  54/138 [==========>...................]
#  - ETA: 0s - loss: 0.3474 - accuracy: 0.9230
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 0.3230 - accuracy: 0.9168
#
#  80/138 [================>.............]
#  - ETA: 0s - loss: 0.2774 - accuracy: 0.9285
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.2457 - accuracy: 0.9368
#
# 103/138 [=====================>........]
#  - ETA: 0s - loss: 0.2606 - accuracy: 0.9293
#
# 115/138 [========================>.....]
#  - ETA: 0s - loss: 0.2663 - accuracy: 0.9245
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0.2447 - accuracy: 0.9303
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.2291 - accuracy: 0.9354
#
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.33198581828718404, 'dropout_cnn_block_three': 0.48014347343263963, 'dropout_cnn_block_two': 0.4686588138493935, 'dropout_dense_block_one': 0.5565649099867984, 'dropout_dense_block_two': 0.3770040349966983}
# accuracy=0.2291162759065628
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.0537 - accuracy: 0.6250
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.1295 - accuracy: 0.9576
#
#  26/138 [====>.........................]
#  - ETA: 0s - loss: 0.4189 - accuracy: 0.9026
#
#  40/138 [=======>......................]
#  - ETA: 0s - loss: 0.2778 - accuracy: 0.9352
#
#  54/138 [==========>...................]
#  - ETA: 0s - loss: 0.2509 - accuracy: 0.9387
#
#  67/138 [=============>................]
#  - ETA: 0s - loss: 0.2196 - accuracy: 0.9454
#
#  80/138 [================>.............]
#  - ETA: 0s - loss: 0.1884 - accuracy: 0.9531
#
#  93/138 [===================>..........]
#  - ETA: 0s - loss: 0.1653 - accuracy: 0.9587
#
# 107/138 [======================>.......]
#  - ETA: 0s - loss: 0.1759 - accuracy: 0.9565
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 0.1588 - accuracy: 0.9606
#
# 131/138 [===========================>..]
#  - ETA: 0s - loss: 0.1508 - accuracy: 0.9623
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.1446 - accuracy: 0.9642
#
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.3284385497748508, 'dropout_cnn_block_three': 0.407775176318378, 'dropout_cnn_block_two': 0.455158462714972, 'dropout_dense_block_one': 0.31584433259725897, 'dropout_dense_block_two': 0.510273644009973}
# accuracy=0.14457860589027405
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.4343 - accuracy: 0.3750
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 0.7684 - accuracy: 0.7563
#
#  27/138 [====>.........................]
#  - ETA: 0s - loss: 1.2863 - accuracy: 0.6817
#
#  39/138 [=======>......................]
#  - ETA: 0s - loss: 0.9436 - accuracy: 0.7572
#
#  52/138 [==========>...................]
#  - ETA: 0s - loss: 0.8874 - accuracy: 0.7530
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 0.7617 - accuracy: 0.7869
#
#  78/138 [===============>..............]
#  - ETA: 0s - loss: 0.6982 - accuracy: 0.8049
#
#  91/138 [==================>...........]
#  - ETA: 0s - loss: 0.6346 - accuracy: 0.8249
#
# 105/138 [=====================>........]
#  - ETA: 0s - loss: 0.6790 - accuracy: 0.8015
#
# 118/138 [========================>.....]
#  - ETA: 0s - loss: 0.6276 - accuracy: 0.8173
#
# 132/138 [===========================>..]
#  - ETA: 0s - loss: 0.5834 - accuracy: 0.8279
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.5672 - accuracy: 0.8338
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.4078475932475728, 'dropout_cnn_block_three': 0.3487616680729415, 'dropout_cnn_block_two': 0.41411729751866383, 'dropout_dense_block_one': 0.44622366160984867, 'dropout_dense_block_two': 0.5722832701433684}
# accuracy=0.5671767592430115
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.2925 - accuracy: 0.6250
#
#  16/138 [==>...........................]
#  - ETA: 0s - loss: 0.5898 - accuracy: 0.8457
#
#  30/138 [=====>........................]
#  - ETA: 0s - loss: 0.8504 - accuracy: 0.7948
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 0.8331 - accuracy: 0.7706
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 0.8522 - accuracy: 0.7522
#
#  69/138 [==============>...............]
#  - ETA: 0s - loss: 0.8499 - accuracy: 0.7233
#
#  83/138 [=================>............]
#  - ETA: 0s - loss: 0.7228 - accuracy: 0.7654
#
#  97/138 [====================>.........]
#  - ETA: 0s - loss: 0.6624 - accuracy: 0.7883
#
# 110/138 [======================>.......]
#  - ETA: 0s - loss: 0.7200 - accuracy: 0.7673
#
# 124/138 [=========================>....]
#  - ETA: 0s - loss: 0.6507 - accuracy: 0.7886
#
# 136/138 [============================>.]
#  - ETA: 0s - loss: 0.6249 - accuracy: 0.7985
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.6190 - accuracy: 0.8009
#
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.44820188926402094, 'dropout_cnn_block_three': 0.3815698320673622, 'dropout_cnn_block_two': 0.3617627882360912, 'dropout_dense_block_one': 0.6826242861011881, 'dropout_dense_block_two': 0.6668027903854907}
# accuracy=0.6190260052680969
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.2377 - accuracy: 0.0625
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 0.2432 - accuracy: 0.9125
#
#  28/138 [=====>........................]
#  - ETA: 0s - loss: 0.2545 - accuracy: 0.9152
#
#  41/138 [=======>......................]
#  - ETA: 0s - loss: 0.2106 - accuracy: 0.9268
#
#  54/138 [==========>...................]
#  - ETA: 0s - loss: 0.2446 - accuracy: 0.9196
#
#  67/138 [=============>................]
#  - ETA: 0s - loss: 0.2315 - accuracy: 0.9240
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 0.1992 - accuracy: 0.9347
#
#  91/138 [==================>...........]
#  - ETA: 0s - loss: 0.1832 - accuracy: 0.9409
#
# 104/138 [=====================>........]
#  - ETA: 0s - loss: 0.1847 - accuracy: 0.9420
#
# 118/138 [========================>.....]
#  - ETA: 0s - loss: 0.1767 - accuracy: 0.9454
#
# 132/138 [===========================>..]
#  - ETA: 0s - loss: 0.1764 - accuracy: 0.9444
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.1784 - accuracy: 0.9444
#
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.3053232638069392, 'dropout_cnn_block_three': 0.33423141268996154, 'dropout_cnn_block_two': 0.4785447206142591, 'dropout_dense_block_one': 0.617770037534483, 'dropout_dense_block_two': 0.4952155149414833}
# accuracy=0.1784335821866989
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.2995 - accuracy: 0.8750
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.1472 - accuracy: 0.9576
#
#  27/138 [====>.........................]
#  - ETA: 0s - loss: 0.5736 - accuracy: 0.9259
#
#  40/138 [=======>......................]
#  - ETA: 0s - loss: 0.3975 - accuracy: 0.9453
#
#  52/138 [==========>...................]
#  - ETA: 0s - loss: 0.3757 - accuracy: 0.9291
#
#  64/138 [============>.................]
#  - ETA: 0s - loss: 0.3201 - accuracy: 0.9370
#
#  76/138 [===============>..............]
#  - ETA: 0s - loss: 0.2821 - accuracy: 0.9428
#
#  85/138 [=================>............]
#  - ETA: 0s - loss: 0.2534 - accuracy: 0.9489
#
#  97/138 [====================>.........]
#  - ETA: 0s - loss: 0.2254 - accuracy: 0.9546
#
# 109/138 [======================>.......]
#  - ETA: 0s - loss: 0.2405 - accuracy: 0.9484
#
# 122/138 [=========================>....]
#  - ETA: 0s - loss: 0.2173 - accuracy: 0.9534
#
# 134/138 [============================>.]
#  - ETA: 0s - loss: 0.2070 - accuracy: 0.9548
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.2116 - accuracy: 0.9531
#
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.42570380852748924, 'dropout_cnn_block_three': 0.3666541169397946, 'dropout_cnn_block_two': 0.3791135751778951, 'dropout_dense_block_one': 0.31886097350737985, 'dropout_dense_block_two': 0.4603799236035356}
# accuracy=0.21159887313842773
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.8337 - accuracy: 0.1250
#
#  16/138 [==>...........................]
#  - ETA: 0s - loss: 0.5434 - accuracy: 0.8848
#
#  29/138 [=====>........................]
#  - ETA: 0s - loss: 0.8467 - accuracy: 0.8373
#
#  41/138 [=======>......................]
#  - ETA: 0s - loss: 0.6584 - accuracy: 0.8765
#
#  52/138 [==========>...................]
#  - ETA: 0s - loss: 0.6756 - accuracy: 0.8317
#
#  65/138 [=============>................]
#  - ETA: 0s - loss: 0.5868 - accuracy: 0.8433
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 0.5266 - accuracy: 0.8358
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.4901 - accuracy: 0.8488
#
# 104/138 [=====================>........]
#  - ETA: 0s - loss: 0.5250 - accuracy: 0.8230
#
# 117/138 [========================>.....]
#  - ETA: 0s - loss: 0.4971 - accuracy: 0.8275
#
# 128/138 [==========================>...]
#  - ETA: 0s - loss: 0.4604 - accuracy: 0.8411
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.4335 - accuracy: 0.8517
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.39645365145857625, 'dropout_cnn_block_three': 0.4995835258669489, 'dropout_cnn_block_two': 0.44119522827469426, 'dropout_dense_block_one': 0.6392338449670404, 'dropout_dense_block_two': 0.5355288883163504}
# accuracy=0.43354910612106323
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.8024 - accuracy: 0.8125
#
#  16/138 [==>...........................]
#  - ETA: 0s - loss: 0.3134 - accuracy: 0.9297
#
#  29/138 [=====>........................]
#  - ETA: 0s - loss: 0.4231 - accuracy: 0.8772
#
#  42/138 [========>.....................]
#  - ETA: 0s - loss: 0.3695 - accuracy: 0.9003
#
#  55/138 [==========>...................]
#  - ETA: 0s - loss: 0.4583 - accuracy: 0.8631
#
#  67/138 [=============>................]
#  - ETA: 0s - loss: 0.4403 - accuracy: 0.8652
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 0.3934 - accuracy: 0.8762
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.3818 - accuracy: 0.8794
#
# 103/138 [=====================>........]
#  - ETA: 0s - loss: 0.4127 - accuracy: 0.8680
#
# 117/138 [========================>.....]
#  - ETA: 0s - loss: 0.4208 - accuracy: 0.8675
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.3945 - accuracy: 0.8719
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.3768 - accuracy: 0.8782
#
# {'batch_size': 180.0, 'dropout_cnn_block_one': 0.32575986432902, 'dropout_cnn_block_three': 0.4670669958771386, 'dropout_cnn_block_two': 0.49571477433391686, 'dropout_dense_block_one': 0.3681521807890531, 'dropout_dense_block_two': 0.33291101829595515}
# accuracy=0.37684398889541626
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.9242 - accuracy: 0.5625
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.2386 - accuracy: 0.9207
#
#  27/138 [====>.........................]
#  - ETA: 0s - loss: 0.2129 - accuracy: 0.9271
#
#  40/138 [=======>......................]
#  - ETA: 0s - loss: 0.1576 - accuracy: 0.9438
#
#  54/138 [==========>...................]
#  - ETA: 0s - loss: 0.1879 - accuracy: 0.9352
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 0.1756 - accuracy: 0.9412
#
#  82/138 [================>.............]
#  - ETA: 0s - loss: 0.1467 - accuracy: 0.9512
#
#  95/138 [===================>..........]
#  - ETA: 0s - loss: 0.1348 - accuracy: 0.9563
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.1612 - accuracy: 0.9496
#
# 118/138 [========================>.....]
#  - ETA: 0s - loss: 0.1468 - accuracy: 0.9542
#
# 131/138 [===========================>..]
#  - ETA: 0s - loss: 0.1419 - accuracy: 0.9568
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.1422 - accuracy: 0.9574
#
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.4089194617672911, 'dropout_cnn_block_three': 0.4395198508140602, 'dropout_cnn_block_two': 0.31695488651607506, 'dropout_dense_block_one': 0.5786409995471729, 'dropout_dense_block_two': 0.3958379849764617}
# accuracy=0.14220789074897766
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.4032 - accuracy: 0.6250
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 1.2148 - accuracy: 0.6208
#
#  28/138 [=====>........................]
#  - ETA: 0s - loss: 1.4571 - accuracy: 0.6038
#
#  41/138 [=======>......................]
#  - ETA: 0s - loss: 1.3267 - accuracy: 0.6326
#
#  55/138 [==========>...................]
#  - ETA: 0s - loss: 1.3739 - accuracy: 0.5972
#
#  69/138 [==============>...............]
#  - ETA: 0s - loss: 1.2686 - accuracy: 0.6336
#
#  80/138 [================>.............]
#  - ETA: 0s - loss: 1.2179 - accuracy: 0.6441
#
#  94/138 [===================>..........]
#  - ETA: 0s - loss: 1.1210 - accuracy: 0.6745
#
# 107/138 [======================>.......]
#  - ETA: 0s - loss: 1.2257 - accuracy: 0.6031
#
# 120/138 [=========================>....]
#  - ETA: 0s - loss: 1.1334 - accuracy: 0.6237
#
# 133/138 [===========================>..]
#  - ETA: 0s - loss: 1.0734 - accuracy: 0.6426
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 1.0881 - accuracy: 0.6463
#
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.48505438345506857, 'dropout_cnn_block_three': 0.38126248778251187, 'dropout_cnn_block_two': 0.4175725459959348, 'dropout_dense_block_one': 0.6863375417719251, 'dropout_dense_block_two': 0.6999717074820411}
# accuracy=1.0881232023239136
#   1/138 [..............................]
#  - ETA: 0s - loss: 3.1537 - accuracy: 0.0625
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 1.3131 - accuracy: 0.5625
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 1.2017 - accuracy: 0.6276
#
#  37/138 [=======>......................]
#  - ETA: 0s - loss: 0.8915 - accuracy: 0.7272
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 1.0010 - accuracy: 0.6849
#
#  63/138 [============>.................]
#  - ETA: 0s - loss: 0.9482 - accuracy: 0.7178
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 0.8688 - accuracy: 0.7350
#
#  90/138 [==================>...........]
#  - ETA: 0s - loss: 0.8432 - accuracy: 0.7316
#
# 103/138 [=====================>........]
#  - ETA: 0s - loss: 0.8738 - accuracy: 0.6990
#
# 116/138 [========================>.....]
#  - ETA: 0s - loss: 0.8957 - accuracy: 0.6751
#
# 129/138 [===========================>..]
#  - ETA: 0s - loss: 0.8329 - accuracy: 0.6953
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.7907 - accuracy: 0.7109
#
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.48882484193899656, 'dropout_cnn_block_three': 0.37759472156228924, 'dropout_cnn_block_two': 0.4124976651852329, 'dropout_dense_block_one': 0.6881781631292053, 'dropout_dense_block_two': 0.6937454071212491}
# accuracy=0.7907477021217346
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.3625 - accuracy: 0.4375
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.5297 - accuracy: 0.8606
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.7890 - accuracy: 0.7826
#
#  39/138 [=======>......................]
#  - ETA: 0s - loss: 0.5724 - accuracy: 0.8277
#
#  52/138 [==========>...................]
#  - ETA: 0s - loss: 0.6357 - accuracy: 0.7855
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 0.5929 - accuracy: 0.8011
#
#  80/138 [================>.............]
#  - ETA: 0s - loss: 0.5134 - accuracy: 0.8309
#
#  93/138 [===================>..........]
#  - ETA: 0s - loss: 0.4852 - accuracy: 0.8347
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.5543 - accuracy: 0.7910
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 0.5106 - accuracy: 0.8114
#
# 133/138 [===========================>..]
#  - ETA: 0s - loss: 0.4816 - accuracy: 0.8198
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.4840 - accuracy: 0.8200
#
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.49826361554491133, 'dropout_cnn_block_three': 0.35991232510612886, 'dropout_cnn_block_two': 0.42124109526855524, 'dropout_dense_block_one': 0.6142098017515327, 'dropout_dense_block_two': 0.6941252312845793}
# accuracy=0.48401951789855957
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.9569 - accuracy: 0.1562
#
#  16/138 [==>...........................]
#  - ETA: 0s - loss: 0.7642 - accuracy: 0.7754
#
#  30/138 [=====>........................]
#  - ETA: 0s - loss: 0.8271 - accuracy: 0.7417
#
#  41/138 [=======>......................]
#  - ETA: 0s - loss: 0.6416 - accuracy: 0.8064
#
#  55/138 [==========>...................]
#  - ETA: 0s - loss: 0.6913 - accuracy: 0.7795
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 0.6670 - accuracy: 0.7784
#
#  78/138 [===============>..............]
#  - ETA: 0s - loss: 0.5977 - accuracy: 0.7929
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.5411 - accuracy: 0.8128
#
# 104/138 [=====================>........]
#  - ETA: 0s - loss: 0.5615 - accuracy: 0.8065
#
# 117/138 [========================>.....]
#  - ETA: 0s - loss: 0.5283 - accuracy: 0.8200
#
# 131/138 [===========================>..]
#  - ETA: 0s - loss: 0.5298 - accuracy: 0.8166
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.5111 - accuracy: 0.8240
#
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.4784023767986531, 'dropout_cnn_block_three': 0.3764134241191221, 'dropout_cnn_block_two': 0.43470124615406136, 'dropout_dense_block_one': 0.5105550656590685, 'dropout_dense_block_two': 0.6952318921841757}
# accuracy=0.5110759735107422
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.5884 - accuracy: 0.0625
#
#  16/138 [==>...........................]
#  - ETA: 0s - loss: 1.1122 - accuracy: 0.5898
#
#  29/138 [=====>........................]
#  - ETA: 0s - loss: 1.3812 - accuracy: 0.5226
#
#  43/138 [========>.....................]
#  - ETA: 0s - loss: 1.3056 - accuracy: 0.5719
#
#  52/138 [==========>...................]
#  - ETA: 0s - loss: 1.3794 - accuracy: 0.5361
#
#  62/138 [============>.................]
#  - ETA: 0s - loss: 1.2785 - accuracy: 0.5635
#
#  75/138 [===============>..............]
#  - ETA: 0s - loss: 1.1235 - accuracy: 0.6171
#
#  88/138 [==================>...........]
#  - ETA: 0s - loss: 1.0218 - accuracy: 0.6605
#
#  99/138 [====================>.........]
#  - ETA: 0s - loss: 0.9664 - accuracy: 0.6771
#
# 111/138 [=======================>......]
#  - ETA: 0s - loss: 1.0034 - accuracy: 0.6548
#
# 123/138 [=========================>....]
#  - ETA: 0s - loss: 0.9285 - accuracy: 0.6855
#
# 137/138 [============================>.]
#  - ETA: 0s - loss: 0.9226 - accuracy: 0.6959
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.9253 - accuracy: 0.6975
#
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.4770010530610145, 'dropout_cnn_block_three': 0.4445820789017276, 'dropout_cnn_block_two': 0.41172559434369144, 'dropout_dense_block_one': 0.659059999666908, 'dropout_dense_block_two': 0.6513048982949787}
# accuracy=0.9252538681030273
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.3440 - accuracy: 0.3125
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 0.8395 - accuracy: 0.6833
#
#  28/138 [=====>........................]
#  - ETA: 0s - loss: 0.9751 - accuracy: 0.7154
#
#  42/138 [========>.....................]
#  - ETA: 0s - loss: 0.8412 - accuracy: 0.7827
#
#  55/138 [==========>...................]
#  - ETA: 0s - loss: 0.8126 - accuracy: 0.7699
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 0.7180 - accuracy: 0.7909
#
#  80/138 [================>.............]
#  - ETA: 0s - loss: 0.6215 - accuracy: 0.8203
#
#  94/138 [===================>..........]
#  - ETA: 0s - loss: 0.5428 - accuracy: 0.8451
#
# 107/138 [======================>.......]
#  - ETA: 0s - loss: 0.5813 - accuracy: 0.8233
#
# 120/138 [=========================>....]
#  - ETA: 0s - loss: 0.5353 - accuracy: 0.8284
#
# 132/138 [===========================>..]
#  - ETA: 0s - loss: 0.5388 - accuracy: 0.8156
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.5263 - accuracy: 0.8213
#
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.47493756372228907, 'dropout_cnn_block_three': 0.4553397319262113, 'dropout_cnn_block_two': 0.4350209676707042, 'dropout_dense_block_one': 0.6499719523836275, 'dropout_dense_block_two': 0.6554043389212775}
# accuracy=0.5263067483901978
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.2620 - accuracy: 0.0625
#
#  17/138 [==>...........................]
#  - ETA: 0s - loss: 1.2315 - accuracy: 0.5423
#
#  30/138 [=====>........................]
#  - ETA: 0s - loss: 1.6565 - accuracy: 0.5188
#
#  42/138 [========>.....................]
#  - ETA: 0s - loss: 1.5952 - accuracy: 0.5037
#
#  56/138 [===========>..................]
#  - ETA: 0s - loss: 1.5705 - accuracy: 0.5089
#
#  70/138 [==============>...............]
#  - ETA: 0s - loss: 1.3900 - accuracy: 0.5705
#
#  83/138 [=================>............]
#  - ETA: 0s - loss: 1.2330 - accuracy: 0.6261
#
#  95/138 [===================>..........]
#  - ETA: 0s - loss: 1.1276 - accuracy: 0.6510
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 1.2008 - accuracy: 0.6097
#
# 120/138 [=========================>....]
#  - ETA: 0s - loss: 1.1176 - accuracy: 0.6396
#
# 134/138 [============================>.]
#  - ETA: 0s - loss: 1.0964 - accuracy: 0.6476
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 1.1111 - accuracy: 0.6506
#
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.46964773144718025, 'dropout_cnn_block_three': 0.432842358870347, 'dropout_cnn_block_two': 0.40355797268634463, 'dropout_dense_block_one': 0.5978399144209395, 'dropout_dense_block_two': 0.42682145791071574}
# accuracy=1.1111321449279785
#   1/138 [..............................]
#  - ETA: 0s - loss: 4.1106 - accuracy: 0.0312
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 0.7163 - accuracy: 0.7937
#
#  25/138 [====>.........................]
#  - ETA: 0s - loss: 0.8191 - accuracy: 0.8150
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 0.6298 - accuracy: 0.8420
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 0.6686 - accuracy: 0.7832
#
#  60/138 [============>.................]
#  - ETA: 0s - loss: 0.6676 - accuracy: 0.7667
#
#  73/138 [==============>...............]
#  - ETA: 0s - loss: 0.5961 - accuracy: 0.7988
#
#  86/138 [=================>............]
#  - ETA: 0s - loss: 0.5184 - accuracy: 0.8270
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.4853 - accuracy: 0.8409
#
# 112/138 [=======================>......]
#  - ETA: 0s - loss: 0.5306 - accuracy: 0.8228
#
# 118/138 [========================>.....]
#  - ETA: 0s - loss: 0.5036 - accuracy: 0.8318
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.4892 - accuracy: 0.8349
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.4700 - accuracy: 0.8426
#
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.4659480793208498, 'dropout_cnn_block_three': 0.42143490658557237, 'dropout_cnn_block_two': 0.344370975630929, 'dropout_dense_block_one': 0.5948996322883292, 'dropout_dense_block_two': 0.444642884007747}
# accuracy=0.47001156210899353
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.5131 - accuracy: 0.7812
#
#  17/138 [==>...........................]
#  - ETA: 0s - loss: 0.3149 - accuracy: 0.9118
#
#  30/138 [=====>........................]
#  - ETA: 0s - loss: 0.5472 - accuracy: 0.9010
#
#  42/138 [========>.....................]
#  - ETA: 0s - loss: 0.4232 - accuracy: 0.9204
#
#  53/138 [==========>...................]
#  - ETA: 0s - loss: 0.4583 - accuracy: 0.8850
#
#  67/138 [=============>................]
#  - ETA: 0s - loss: 0.3891 - accuracy: 0.9016
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.3246 - accuracy: 0.9182
#
#  94/138 [===================>..........]
#  - ETA: 0s - loss: 0.2855 - accuracy: 0.9285
#
# 108/138 [======================>.......]
#  - ETA: 0s - loss: 0.3007 - accuracy: 0.9233
#
# 120/138 [=========================>....]
#  - ETA: 0s - loss: 0.2718 - accuracy: 0.9310
#
# 133/138 [===========================>..]
#  - ETA: 0s - loss: 0.2550 - accuracy: 0.9349
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.2475 - accuracy: 0.9365
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.3648688420238428, 'dropout_cnn_block_three': 0.4299881225368827, 'dropout_cnn_block_two': 0.3994259990919646, 'dropout_dense_block_one': 0.5071849635694426, 'dropout_dense_block_two': 0.4295660505625797}
# accuracy=0.2474851757287979
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.7669 - accuracy: 0.0625
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.4565 - accuracy: 0.8237
#
#  27/138 [====>.........................]
#  - ETA: 0s - loss: 0.7328 - accuracy: 0.8310
#
#  41/138 [=======>......................]
#  - ETA: 0s - loss: 0.5863 - accuracy: 0.8575
#
#  55/138 [==========>...................]
#  - ETA: 0s - loss: 0.6153 - accuracy: 0.8295
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 0.5998 - accuracy: 0.7978
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.5205 - accuracy: 0.8225
#
#  95/138 [===================>..........]
#  - ETA: 0s - loss: 0.4598 - accuracy: 0.8457
#
# 108/138 [======================>.......]
#  - ETA: 0s - loss: 0.5047 - accuracy: 0.8313
#
# 121/138 [=========================>....]
#  - ETA: 0s - loss: 0.4572 - accuracy: 0.8476
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.4520 - accuracy: 0.8481
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.4341 - accuracy: 0.8558
#
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.499887635623133, 'dropout_cnn_block_three': 0.39048538953984724, 'dropout_cnn_block_two': 0.37672027193817337, 'dropout_dense_block_one': 0.6258711524404866, 'dropout_dense_block_two': 0.4247607301078318}
# accuracy=0.434068500995636
# 100%|██████████| 30/30 [07:46<00:00, 15.56s/it, best loss: -1.1111321449279785]
